# %%
 # !pip install segmentation_models

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import os
import cv2
import glob 
from PIL import Image
import segmentation_models as sm
import random
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, Dropout,BatchNormalization, Lambda
from sklearn.model_selection import train_test_split
from keras.models import Model
from keras import backend as K
# Out:
# Segmentation Models: using `keras` framework.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Images come in many sizes: 797x644, 509x544, 682x658, 1099x846, 1126x1058, 859x838, 1817x2061,  2149x1479​
#72 images grouped into 6 larger tiles
root_directory = '/content/gdrive/MyDrive/PIBIC/aerial_dubai_semantic_segmentation_dataset/'

# %%
images_dataset = []
masks_dataset = []

for path, subdirs, files in os.walk(root_directory):
  dirname = path.split(os.path.sep)[-1]
  
  if dirname == 'images':
    images = os.listdir(path)
    images.sort()
    for count,image_name in enumerate(images):
        if image_name.endswith(".jpg"):
            subdir_image_path = os.path.join(path,image_name)
            image  = cv2.imread(subdir_image_path,1)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)#IMREAD_COLOR = 1)
            image = cv2.resize(image,(512,512))
            images_dataset.append(image)
           
for path, subdirs, files in os.walk(root_directory):
  dirname = path.split(os.path.sep)[-1]
  
  if dirname == 'masks':
    masks = os.listdir(path)
    masks.sort()
    for count,mask_name in enumerate(masks):
        if mask_name.endswith(".png"):
            subdir_mask_path = os.path.join(path,mask_name)
            mask = cv2.imread(subdir_mask_path,1) #IMREAD_COLOR = 1)
            mask = cv2.cvtColor(mask,cv2.COLOR_BGR2RGB)
            mask = cv2.resize(mask,(512,512))
            masks_dataset.append(mask)
            
images_dataset = np.array(images_dataset) 
masks_dataset = np.array(masks_dataset)

# %%
print(images_dataset.shape)
# Out:
# (72, 512, 512, 3)

# %% [markdown]
# ## visualização
#
# ---

# %%
def visualize(images,masks):
    i = 0
    for i in range(0,10):
        img_number = random.randint(0,len(images)-1)
        img = images[img_number]
        mask = masks[img_number]
        plt.figure(figsize=(12, 8))
        plt.subplot(221)
        plt.title('Image')
        plt.imshow(img)
        plt.subplot(222)
        plt.title('Semantic Segmentation Mask')
        plt.imshow(mask)
        plt.show()
        i+=1     

visualize(images_dataset,masks_dataset)

# %% [markdown]
# # onehot coding
#
# ---

# %% [markdown]
#  Now replace RGB to integer values to be used as labels.
# Find pixels with combination of RGB for the above defined arrays...
# if matches then replace all values in that pixel with a specific integer

# %%
color_dict = {0: (60, 16, 152),
1: (132, 41, 246),
 2: (110, 193, 228),
 3: (254, 221, 58),
 4: (226, 169, 41),
 5: (155, 155, 155)}

label_dict = {0: 'building',
 1: 'land',
 2: 'road',
 3: 'vegetation',
 4: 'water',
 5: 'unlabeled'}


def rgb_to_onehot(rgb_image,colormap = color_dict): 
  num_classes = len(colormap)
  #print(num_classes)
  shape = rgb_image.shape[:2]+(num_classes,) #544,509,6
  encoded_image = np.zeros(shape, dtype=np.int8 ) #Return a new array of given shape and type
  for i, cls in enumerate(colormap):
    encoded_image[:,:,i] = np.all(rgb_image.reshape( (-1,3) ) == colormap[i], axis=1).reshape(shape[:2])
  return encoded_image

def onehot_to_rgb(onehot_image, colormap = color_dict):

    single_layer = np.argmax(onehot_image, axis=-1)
    output = np.zeros( onehot_image.shape[:2]+(3,) )
    for k in colormap.keys():
        output[single_layer==k] = colormap[k]
    return np.uint8(output)

# %%
masks_encoded = []
for count,mask in enumerate(masks_dataset):
  mask = rgb_to_onehot(mask,color_dict)
  masks_encoded.append(mask)

masks_encoded = np.array(masks_encoded)
print(masks_encoded.shape)
#onehot_masks = np.expand_dims(onehot_masks, axis=3)
# Out:
# (72, 512, 512, 6)

# %% [markdown]
# # label coding
#
# ---

# %%
building = np.array([60,16,152])
land = np.array([132,41,246])
road = np.array([110,193,228])
vegetation = np.array([254,221,58])
water = np.array([226,169,41])
unlabeled = np.array([155,155,155])


def rgb_to_2dlabel(image):
    image_seg = np.zeros(image.shape,dtype=np.uint8)
    image_seg [np.all(image == building,axis=-1)] = 0
    image_seg [np.all(image == land,axis=-1)] = 1
    image_seg [np.all(image == road,axis=-1)] = 2
    image_seg [np.all(image == vegetation,axis=-1)] = 3
    image_seg [np.all(image == water,axis=-1)] = 4
    image_seg [np.all(image == unlabeled,axis=-1)] = 5
    
    image_seg = image_seg[:,:,0]  #Just take the first channel, no need for all 3 channels
    
    return image_seg

# %%
masks = []

for count, mask in enumerate(masks_dataset):
  mask = rgb_to_2dlabel(mask)
  masks.append(mask)    

masks = np.array(masks)
print(masks.shape)
#masks = np.expand_dims(masks, axis=3)
print("Unique labels in label dataset are: ", np.unique(masks))
# Out:
# (72, 512, 512)
# Unique labels in label dataset are:  [0 1 2 3 4 5]

# %%
n_classes = len(np.unique(masks))
labels_cat = tf.keras.utils.to_categorical(masks, num_classes=n_classes)
#labels_cat é igual ao masks_encoded

# %% [markdown]
# # Pre-processamento do modelo
#
# ---

# %%
#images_dataset = tf.keras.utils.normalize(images_dataset, axis=1)
X_train, X_test, y_train, y_test = train_test_split(images_dataset,labels_cat, test_size = 0.20, random_state = 42)

# %%
weights = [0.1666, 0.1666, 0.1666, 0.1666, 0.1666, 0.1666]
dice_loss = sm.losses.DiceLoss(class_weights=weights) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# %% [markdown]
# # Model U-net

# %%
def multi_unet_model(n_classes=4, IMG_HEIGHT=512, IMG_WIDTH=512, IMG_CHANNELS=1):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    s = Lambda(lambda x: x / 255)(inputs)
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.2)(c1)  # Original 0.1
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.2)(c2)  # Original 0.1
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
     
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)
     
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)
     
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
    
    #Expansive path 
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
     
    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
     
    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.2)(c8)  # Original 0.1
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
     
    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.2)(c9)  # Original 0.1
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
     
    outputs = Conv2D(n_classes, (1, 1), activation='softmax')(c9)
     
    model = Model(inputs=[inputs], outputs=[outputs])

    return model

# %% [markdown]
# # Métricas e compilação

# %%
# compara membros de dois sets distintos para ver qual membro compartilha o mesmo conjunto e qual é distinto. SEmelhante ao IOU
def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

# %%
metrics=['accuracy']#jacard_coef

# %%
n_classes = 6

def get_model():
    return multi_unet_model(n_classes, IMG_HEIGHT = X_train.shape[1], IMG_WIDTH = X_train.shape[2], IMG_CHANNELS = X_train.shape[3])

model = get_model()
#model.compile(optimizer='adam', loss=total_loss, metrics=metrics)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=metrics)
model.summary()

# %%
history1 = model.fit(X_train, y_train, 
                    batch_size = 16, 
                    verbose=1, 
                    epochs=100, 
                    validation_data=(X_test, y_test), 
                    shuffle=False)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 21s 3s/step - loss: 165.2239 - accuracy: 0.1144 - val_loss: 46.2994 - val_accuracy: 0.1214
# Epoch 2/100
# 4/4 [==============================] - 2s 586ms/step - loss: 52.1465 - accuracy: 0.2031 - val_loss: 14.9051 - val_accuracy: 0.3495
# Epoch 3/100
# 4/4 [==============================] - 2s 576ms/step - loss: 29.1952 - accuracy: 0.2869 - val_loss: 11.1188 - val_accuracy: 0.5112
# Epoch 4/100
# 4/4 [==============================] - 2s 587ms/step - loss: 20.7624 - accuracy: 0.3053 - val_loss: 6.7057 - val_accuracy: 0.5077
# Epoch 5/100
# 4/4 [==============================] - 2s 609ms/step - loss: 15.5257 - accuracy: 0.2852 - val_loss: 4.1699 - val_accuracy: 0.4752
# Epoch 6/100
# 4/4 [==============================] - 2s 596ms/step - loss: 12.2363 - accuracy: 0.2623 - val_loss: 3.2869 - val_accuracy: 0.4644
# Epoch 7/100
# 4/4 [==============================] - 2s 582ms/step - loss: 9.5974 - accuracy: 0.2605 - val_loss: 2.6489 - val_accuracy: 0.4785
# Epoch 8/100
# 4/4 [==============================] - 2s 587ms/step - loss: 7.5367 - accuracy: 0.2632 - val_loss: 2.3489 - val_accuracy: 0.4459
# Epoch 9/100
# 4/4 [==============================] - 2s 589ms/step - loss: 6.0499 - accuracy: 0.2614 - val_loss: 2.2248 - val_accuracy: 0.3268
# Epoch 10/100
# 4/4 [==============================] - 2s 587ms/step - loss: 4.8515 - accuracy: 0.2578 - val_loss: 2.0724 - val_accuracy: 0.2542
# Epoch 11/100
# 4/4 [==============================] - 2s 617ms/step - loss: 3.8531 - accuracy: 0.2506 - val_loss: 1.9344 - val_accuracy: 0.2347
# Epoch 12/100
# 4/4 [==============================] - 2s 596ms/step - loss: 3.0115 - accuracy: 0.2386 - val_loss: 1.8461 - val_accuracy: 0.2207
# Epoch 13/100
# 4/4 [==============================] - 2s 582ms/step - loss: 2.3036 - accuracy: 0.2275 - val_loss: 1.7884 - val_accuracy: 0.1762
# Epoch 14/100
# 4/4 [==============================] - 2s 585ms/step - loss: 1.8566 - accuracy: 0.3394 - val_loss: 1.7698 - val_accuracy: 0.5381
# Epoch 15/100
# 4/4 [==============================] - 2s 591ms/step - loss: 1.7864 - accuracy: 0.4268 - val_loss: 1.7643 - val_accuracy: 0.5392
# Epoch 16/100
# 4/4 [==============================] - 2s 578ms/step - loss: 1.7714 - accuracy: 0.4303 - val_loss: 1.7592 - val_accuracy: 0.5396
# Epoch 17/100
# 4/4 [==============================] - 3s 727ms/step - loss: 1.7647 - accuracy: 0.4311 - val_loss: 1.7531 - val_accuracy: 0.5398
# Epoch 18/100
# 4/4 [==============================] - 3s 708ms/step - loss: 1.7589 - accuracy: 0.4315 - val_loss: 1.7473 - val_accuracy: 0.5402
# Epoch 19/100
# 4/4 [==============================] - 2s 580ms/step - loss: 1.7533 - accuracy: 0.4318 - val_loss: 1.7419 - val_accuracy: 0.5406
# Epoch 20/100
# 4/4 [==============================] - 2s 578ms/step - loss: 1.7481 - accuracy: 0.4320 - val_loss: 1.7368 - val_accuracy: 0.5408
# Epoch 21/100
# 4/4 [==============================] - 2s 582ms/step - loss: 1.7430 - accuracy: 0.4321 - val_loss: 1.7319 - val_accuracy: 0.5410
# Epoch 22/100
# 4/4 [==============================] - 2s 584ms/step - loss: 1.7384 - accuracy: 0.4322 - val_loss: 1.7272 - val_accuracy: 0.5411
# Epoch 23/100
# 4/4 [==============================] - 2s 621ms/step - loss: 1.7338 - accuracy: 0.4323 - val_loss: 1.7226 - val_accuracy: 0.5412
# Epoch 24/100
# 4/4 [==============================] - 2s 590ms/step - loss: 1.7294 - accuracy: 0.4323 - val_loss: 1.7182 - val_accuracy: 0.5413
# Epoch 25/100
# 4/4 [==============================] - 2s 595ms/step - loss: 1.7253 - accuracy: 0.4324 - val_loss: 1.7138 - val_accuracy: 0.5415
# Epoch 26/100
# 4/4 [==============================] - 2s 579ms/step - loss: 1.7212 - accuracy: 0.4324 - val_loss: 1.7096 - val_accuracy: 0.5416
# Epoch 27/100
# 4/4 [==============================] - 2s 576ms/step - loss: 1.7173 - accuracy: 0.4325 - val_loss: 1.7054 - val_accuracy: 0.5418
# Epoch 28/100
# 4/4 [==============================] - 2s 585ms/step - loss: 1.7134 - accuracy: 0.4325 - val_loss: 1.7014 - val_accuracy: 0.5419
# Epoch 29/100
# 4/4 [==============================] - 2s 616ms/step - loss: 1.7096 - accuracy: 0.4326 - val_loss: 1.6974 - val_accuracy: 0.5420
# Epoch 30/100
# 4/4 [==============================] - 2s 589ms/step - loss: 1.7060 - accuracy: 0.4326 - val_loss: 1.6935 - val_accuracy: 0.5422
# Epoch 31/100
# 4/4 [==============================] - 2s 577ms/step - loss: 1.7024 - accuracy: 0.4326 - val_loss: 1.6897 - val_accuracy: 0.5423
# Epoch 32/100
# 4/4 [==============================] - 2s 587ms/step - loss: 1.6989 - accuracy: 0.4327 - val_loss: 1.6859 - val_accuracy: 0.5424
# Epoch 33/100
# 4/4 [==============================] - 2s 591ms/step - loss: 1.6955 - accuracy: 0.4327 - val_loss: 1.6822 - val_accuracy: 0.5426
# Epoch 34/100
# 4/4 [==============================] - 2s 582ms/step - loss: 1.6921 - accuracy: 0.4327 - val_loss: 1.6786 - val_accuracy: 0.5427
# Epoch 35/100
# 4/4 [==============================] - 3s 639ms/step - loss: 1.6888 - accuracy: 0.4328 - val_loss: 1.6750 - val_accuracy: 0.5428
# Epoch 36/100
# 4/4 [==============================] - 2s 574ms/step - loss: 1.6856 - accuracy: 0.4328 - val_loss: 1.6715 - val_accuracy: 0.5430
# Epoch 37/100
# 4/4 [==============================] - 2s 587ms/step - loss: 1.6824 - accuracy: 0.4328 - val_loss: 1.6680 - val_accuracy: 0.5431
# Epoch 38/100
# 4/4 [==============================] - 2s 573ms/step - loss: 1.6792 - accuracy: 0.4329 - val_loss: 1.6646 - val_accuracy: 0.5432
# Epoch 39/100
# 4/4 [==============================] - 2s 573ms/step - loss: 1.6761 - accuracy: 0.4329 - val_loss: 1.6612 - val_accuracy: 0.5432
# Epoch 40/100
# 4/4 [==============================] - 2s 623ms/step - loss: 1.6730 - accuracy: 0.4329 - val_loss: 1.6579 - val_accuracy: 0.5433
# Epoch 41/100
# 4/4 [==============================] - 3s 632ms/step - loss: 1.6700 - accuracy: 0.4329 - val_loss: 1.6546 - val_accuracy: 0.5434
# Epoch 42/100
# 4/4 [==============================] - 2s 577ms/step - loss: 1.6671 - accuracy: 0.4329 - val_loss: 1.6513 - val_accuracy: 0.5434
# Epoch 43/100
# 4/4 [==============================] - 2s 587ms/step - loss: 1.6641 - accuracy: 0.4330 - val_loss: 1.6481 - val_accuracy: 0.5434
# Epoch 44/100
# 4/4 [==============================] - 2s 586ms/step - loss: 1.6612 - accuracy: 0.4330 - val_loss: 1.6449 - val_accuracy: 0.5435
# Epoch 45/100
# 4/4 [==============================] - 2s 597ms/step - loss: 1.6583 - accuracy: 0.4330 - val_loss: 1.6418 - val_accuracy: 0.5435
# Epoch 46/100
# 4/4 [==============================] - 2s 617ms/step - loss: 1.6555 - accuracy: 0.4330 - val_loss: 1.6386 - val_accuracy: 0.5436
# Epoch 47/100
# 4/4 [==============================] - 2s 617ms/step - loss: 1.6527 - accuracy: 0.4330 - val_loss: 1.6356 - val_accuracy: 0.5436
# Epoch 48/100
# 4/4 [==============================] - 2s 586ms/step - loss: 1.6500 - accuracy: 0.4330 - val_loss: 1.6325 - val_accuracy: 0.5436
# Epoch 49/100
# 4/4 [==============================] - 2s 583ms/step - loss: 1.6472 - accuracy: 0.4330 - val_loss: 1.6295 - val_accuracy: 0.5436
# Epoch 50/100
# 4/4 [==============================] - 2s 584ms/step - loss: 1.6445 - accuracy: 0.4331 - val_loss: 1.6265 - val_accuracy: 0.5437
# Epoch 51/100
# 4/4 [==============================] - 2s 591ms/step - loss: 1.6419 - accuracy: 0.4331 - val_loss: 1.6236 - val_accuracy: 0.5437
# Epoch 52/100
# 4/4 [==============================] - 3s 638ms/step - loss: 1.6393 - accuracy: 0.4331 - val_loss: 1.6206 - val_accuracy: 0.5437
# Epoch 53/100
# 4/4 [==============================] - 2s 586ms/step - loss: 1.6367 - accuracy: 0.4331 - val_loss: 1.6177 - val_accuracy: 0.5437
# Epoch 54/100
# 4/4 [==============================] - 2s 587ms/step - loss: 1.6341 - accuracy: 0.4331 - val_loss: 1.6149 - val_accuracy: 0.5437
# Epoch 55/100
# 4/4 [==============================] - 2s 597ms/step - loss: 1.6316 - accuracy: 0.4331 - val_loss: 1.6120 - val_accuracy: 0.5437
# Epoch 56/100
# 4/4 [==============================] - 2s 581ms/step - loss: 1.6291 - accuracy: 0.4332 - val_loss: 1.6092 - val_accuracy: 0.5438
# Epoch 57/100
# 4/4 [==============================] - 2s 582ms/step - loss: 1.6266 - accuracy: 0.4331 - val_loss: 1.6064 - val_accuracy: 0.5438
# Epoch 58/100
# 4/4 [==============================] - 2s 590ms/step - loss: 1.6242 - accuracy: 0.4332 - val_loss: 1.6037 - val_accuracy: 0.5438
# Epoch 59/100
# 4/4 [==============================] - 2s 613ms/step - loss: 1.6218 - accuracy: 0.4332 - val_loss: 1.6009 - val_accuracy: 0.5438
# Epoch 60/100
# 4/4 [==============================] - 2s 609ms/step - loss: 1.6194 - accuracy: 0.4332 - val_loss: 1.5982 - val_accuracy: 0.5438
# Epoch 61/100
# 4/4 [==============================] - 2s 633ms/step - loss: 1.6171 - accuracy: 0.4332 - val_loss: 1.5956 - val_accuracy: 0.5438
# Epoch 62/100
# 4/4 [==============================] - 3s 621ms/step - loss: 1.6148 - accuracy: 0.4332 - val_loss: 1.5929 - val_accuracy: 0.5438
# Epoch 63/100
# 4/4 [==============================] - 2s 604ms/step - loss: 1.6124 - accuracy: 0.4332 - val_loss: 1.5903 - val_accuracy: 0.5438
# Epoch 64/100
# 4/4 [==============================] - 3s 623ms/step - loss: 1.6102 - accuracy: 0.4332 - val_loss: 1.5877 - val_accuracy: 0.5439
# Epoch 65/100
# 4/4 [==============================] - 2s 588ms/step - loss: 1.6079 - accuracy: 0.4332 - val_loss: 1.5851 - val_accuracy: 0.5439
# Epoch 66/100
# 4/4 [==============================] - 2s 588ms/step - loss: 1.6057 - accuracy: 0.4332 - val_loss: 1.5825 - val_accuracy: 0.5439
# Epoch 67/100
# 4/4 [==============================] - 2s 596ms/step - loss: 1.6035 - accuracy: 0.4332 - val_loss: 1.5800 - val_accuracy: 0.5439
# Epoch 68/100
# 4/4 [==============================] - 2s 581ms/step - loss: 1.6013 - accuracy: 0.4332 - val_loss: 1.5775 - val_accuracy: 0.5439
# Epoch 69/100
# 4/4 [==============================] - 2s 625ms/step - loss: 1.5992 - accuracy: 0.4332 - val_loss: 1.5750 - val_accuracy: 0.5439
# Epoch 70/100
# 4/4 [==============================] - 2s 608ms/step - loss: 1.5971 - accuracy: 0.4332 - val_loss: 1.5725 - val_accuracy: 0.5439
# Epoch 71/100
# 4/4 [==============================] - 2s 590ms/step - loss: 1.5950 - accuracy: 0.4332 - val_loss: 1.5700 - val_accuracy: 0.5439
# Epoch 72/100
# 4/4 [==============================] - 2s 597ms/step - loss: 1.5929 - accuracy: 0.4333 - val_loss: 1.5676 - val_accuracy: 0.5439
# Epoch 73/100
# 4/4 [==============================] - 2s 585ms/step - loss: 1.5909 - accuracy: 0.4332 - val_loss: 1.5652 - val_accuracy: 0.5439
# Epoch 74/100
# 4/4 [==============================] - 2s 582ms/step - loss: 1.5888 - accuracy: 0.4333 - val_loss: 1.5628 - val_accuracy: 0.5439
# Epoch 75/100
# 4/4 [==============================] - 2s 604ms/step - loss: 1.5868 - accuracy: 0.4333 - val_loss: 1.5605 - val_accuracy: 0.5439
# Epoch 76/100
# 4/4 [==============================] - 2s 624ms/step - loss: 1.5848 - accuracy: 0.4333 - val_loss: 1.5581 - val_accuracy: 0.5439
# Epoch 77/100
# 4/4 [==============================] - 2s 585ms/step - loss: 1.5828 - accuracy: 0.4333 - val_loss: 1.5558 - val_accuracy: 0.5440
# Epoch 78/100
# 4/4 [==============================] - 2s 588ms/step - loss: 1.5809 - accuracy: 0.4333 - val_loss: 1.5535 - val_accuracy: 0.5440
# Epoch 79/100
# 4/4 [==============================] - 2s 604ms/step - loss: 1.5789 - accuracy: 0.4333 - val_loss: 1.5513 - val_accuracy: 0.5440
# Epoch 80/100
# 4/4 [==============================] - 2s 589ms/step - loss: 1.5771 - accuracy: 0.4333 - val_loss: 1.5490 - val_accuracy: 0.5440
# Epoch 81/100
# 4/4 [==============================] - 2s 615ms/step - loss: 1.5752 - accuracy: 0.4333 - val_loss: 1.5468 - val_accuracy: 0.5440
# Epoch 82/100
# 4/4 [==============================] - 2s 611ms/step - loss: 1.5733 - accuracy: 0.4333 - val_loss: 1.5446 - val_accuracy: 0.5440
# Epoch 83/100
# 4/4 [==============================] - 2s 591ms/step - loss: 1.5715 - accuracy: 0.4333 - val_loss: 1.5424 - val_accuracy: 0.5440
# Epoch 84/100
# 4/4 [==============================] - 2s 589ms/step - loss: 1.5697 - accuracy: 0.4333 - val_loss: 1.5402 - val_accuracy: 0.5440
# Epoch 85/100
# 4/4 [==============================] - 2s 593ms/step - loss: 1.5679 - accuracy: 0.4333 - val_loss: 1.5381 - val_accuracy: 0.5440
# Epoch 86/100
# 4/4 [==============================] - 2s 586ms/step - loss: 1.5661 - accuracy: 0.4333 - val_loss: 1.5360 - val_accuracy: 0.5440
# Epoch 87/100
# 4/4 [==============================] - 2s 615ms/step - loss: 1.5644 - accuracy: 0.4333 - val_loss: 1.5339 - val_accuracy: 0.5440
# Epoch 88/100
# 4/4 [==============================] - 2s 611ms/step - loss: 1.5627 - accuracy: 0.4333 - val_loss: 1.5318 - val_accuracy: 0.5440
# Epoch 89/100
# 4/4 [==============================] - 2s 580ms/step - loss: 1.5609 - accuracy: 0.4333 - val_loss: 1.5297 - val_accuracy: 0.5440
# Epoch 90/100
# 4/4 [==============================] - 2s 594ms/step - loss: 1.5593 - accuracy: 0.4333 - val_loss: 1.5277 - val_accuracy: 0.5440
# Epoch 91/100
# 4/4 [==============================] - 2s 596ms/step - loss: 1.5576 - accuracy: 0.4333 - val_loss: 1.5257 - val_accuracy: 0.5440
# Epoch 92/100
# 4/4 [==============================] - 2s 603ms/step - loss: 1.5559 - accuracy: 0.4333 - val_loss: 1.5237 - val_accuracy: 0.5440
# Epoch 93/100
# 4/4 [==============================] - 3s 640ms/step - loss: 1.5544 - accuracy: 0.4333 - val_loss: 1.5217 - val_accuracy: 0.5440
# Epoch 94/100
# 4/4 [==============================] - 2s 607ms/step - loss: 1.5527 - accuracy: 0.4333 - val_loss: 1.5197 - val_accuracy: 0.5440
# Epoch 95/100
# 4/4 [==============================] - 2s 599ms/step - loss: 1.5512 - accuracy: 0.4333 - val_loss: 1.5178 - val_accuracy: 0.5440
# Epoch 96/100
# 4/4 [==============================] - 2s 598ms/step - loss: 1.5496 - accuracy: 0.4333 - val_loss: 1.5159 - val_accuracy: 0.5440
# Epoch 97/100
# 4/4 [==============================] - 2s 594ms/step - loss: 1.5480 - accuracy: 0.4333 - val_loss: 1.5140 - val_accuracy: 0.5440
# Epoch 98/100
# 4/4 [==============================] - 2s 628ms/step - loss: 1.5465 - accuracy: 0.4333 - val_loss: 1.5121 - val_accuracy: 0.5440
# Epoch 99/100
# 4/4 [==============================] - 3s 624ms/step - loss: 1.5450 - accuracy: 0.4333 - val_loss: 1.5102 - val_accuracy: 0.5440
# Epoch 100/100
# 4/4 [==============================] - 2s 586ms/step - loss: 1.5435 - accuracy: 0.4333 - val_loss: 1.5084 - val_accuracy: 0.5440

# %% [markdown]
# # Plotting

# %%
history = history1
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
y_pred=model.predict(X_test)
y_pred_argmax=np.argmax(y_pred, axis=3)
y_test_argmax=np.argmax(y_test, axis=3)
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test_argmax[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img)
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth)
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img)
plt.show()
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
# individual classes -> iou = true_positives / (true_positives + false_positives + false_negatives)

from keras.metrics import MeanIoU
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(y_test_argmax, y_pred_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
